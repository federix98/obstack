# %%
import pandas as pd

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(
        hosts="http://192.168.195.78:9200",
        basic_auth=("user", "password"))

# %%
es.info()
# Out:
# {'name': '79e8d2a7d7e7',
#  'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'ydOQxjPIS3G3vsNk9di2Qw',
#  'version': {'number': '7.6.0',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': '7f634e9f44834fbc12724506cc1da681b0c3b1e3',
#   'build_date': '2020-02-06T00:09:00.449973Z',
#   'build_snapshot': False,
#   'lucene_version': '8.4.0',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
import requests

requests.get("http://192.168.195.78:9200").json()

# %%
resp = es.search(index="jaeger-span-2022-05-19", query={"match_all":{}}, size=10000)
print("Got %d Hits:" % resp['hits']['total']['value'])
# for hit in resp['hits']['hits']:
#     print("%(timestamp)s" % hit["_source"])
# Out:
# Got 10000 Hits:

# %%
class DatasetBuilder:
    
    def __build_serialized_dataset(self, data, delta_time = 1000, start_ts = 1652979000000):
        values_to_add = []

        for i, hit in enumerate(data['hits']['hits']):
            # print(hit['_source'].keys())

            data_source = hit['_source']

            spanID = data_source['spanID']
            traceID = data_source['traceID']
            duration = data_source['duration']
            process = data_source['process']['serviceName']
            operation = data_source['operationName']

            startTimeMillis = hit['_source']['startTimeMillis']

            frame = int((startTimeMillis - start_ts) / delta_time)


            if spanID == traceID:
                tp = "entry"
            else:
                tp = "end"

            dict_vals = {
                "time_frame": frame,
                "type": tp,
                "duration": duration,
                "service": process + ":" + operation
            }    

            values_to_add.append(dict_vals)
            # break

        dataset = pd.DataFrame.from_records(values_to_add)
        return dataset
    
    def __build_final_dataset(self, serialized_dataset):
        values_to_add = []

        for i, frame in enumerate(serialized_dataset['time_frame'].unique()):
            # print(frame)
            frame_values = {
                "time_frame": frame
            }

            ds_subset = serialized_dataset[serialized_dataset["time_frame"] == frame]

            # print(ds_subset)

            services = (ds_subset["service"] + "___" + ds_subset["type"]).unique()

            # print(services)

            for service in services:
                service_name, tp = service.split("___")
                if tp == "entry":
                    subdf = ds_subset.loc[(ds_subset["service"] == service_name) & (ds_subset["type"] == tp)]
                    frame_values["AVG_EXTIME_ENTRYPOINT_" + service_name] = sum(list(subdf["duration"])) / len(subdf)
                elif tp == "end":
                    subdf = ds_subset.loc[(ds_subset["service"] == service_name) & (ds_subset["type"] == tp)]
                    frame_values["N_INVOC_API_ENDPOINT_" + service_name] = len(subdf)

            # print(frame_values)

            values_to_add.append(frame_values)


        final_dataset = pd.DataFrame.from_records(values_to_add)
        return final_dataset
    
    def build_dataset(self, data, delta_time = 100, start_ts = 1652979000000):
        _serialized_ds = self.__build_serialized_dataset(data = data, delta_time = delta_time, start_ts = start_ts)
        return self.__build_final_dataset(_serialized_ds)

# %%
db = DatasetBuilder()

df = db.build_dataset(data=resp)

df
# Out:
#      time_frame  AVG_EXTIME_ENTRYPOINT_ts-auth-service:getToken  \
# 0          4907                                        498851.0
# 1          4913                                        121710.0
# 2          4923                                        116436.0
# 3          4925                                             NaN
# 4          4926                                             NaN
# ..          ...                                             ...
# 143        5063                                             NaN
# 144        5064                                             NaN
# 145        5065                                             NaN
# 146        5066                                             NaN
# 147        5067                                             NaN
#
#      AVG_EXTIME_ENTRYPOINT_ts-travel-plan-service:getByCheapest  \
# 0                                                  NaN
# 1                                            4598092.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#      N_INVOC_API_ENDPOINT_ts-ticketinfo-service:GET  \
# 0                                               NaN
# 1                                               NaN
# 2                                               2.0
# 3                                               1.0
# 4                                               NaN
# ..                                              ...
# 143                                             8.0
# 144                                             NaN
# 145                                             NaN
# 146                                             NaN
# 147                                             NaN
#
#      N_INVOC_API_ENDPOINT_ts-basic-service:queryForStationId  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  3.0
# 4                                                  NaN
# ..                                                 ...
# 143                                               10.0
# 144                                                8.0
# 145                                                1.0
# 146                                                NaN
# 147                                                NaN
#
#      N_INVOC_API_ENDPOINT_ts-ticketinfo-service:queryForStationId  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  1.0
# 4                                                  NaN
# ..                                                 ...
# 143                                                7.0
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#      N_INVOC_API_ENDPOINT_ts-basic-service:GET  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          3.0
# ..                                         ...
# 143                                       25.0
# 144                                       24.0
# 145                                        5.0
# 146                                        NaN
# 147                                        NaN
#
#      N_INVOC_API_ENDPOINT_ts-route-service:queryById  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 143                                             12.0
# 144                                              8.0
# 145                                             11.0
# 146                                             18.0
# 147                                              NaN
#
#      N_INVOC_API_ENDPOINT_ts-travel-service:GET  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 143                                        26.0
# 144                                        21.0
# 145                                         9.0
# 146                                         NaN
# 147                                         NaN
#
#      N_INVOC_API_ENDPOINT_ts-travel-service:POST  ...  \
# 0                                            NaN  ...
# 1                                            NaN  ...
# 2                                            NaN  ...
# 3                                            NaN  ...
# 4                                            NaN  ...
# ..                                           ...  ...
# 143                                          4.0  ...
# 144                                          4.0  ...
# 145                                          NaN  ...
# 146                                          NaN  ...
# 147                                          NaN  ...
#
#      N_INVOC_API_ENDPOINT_ts-order-service:modifyOrder  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#      AVG_EXTIME_ENTRYPOINT_ts-order-service:getOrderById  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#      AVG_EXTIME_ENTRYPOINT_ts-consign-service:findByOrderId  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#      N_INVOC_API_ENDPOINT_ts-cancel-service:GET  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 143                                         NaN
# 144                                         NaN
# 145                                         NaN
# 146                                         NaN
# 147                                         NaN
#
#      N_INVOC_API_ENDPOINT_ts-order-service:saveOrderInfo  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#      N_INVOC_API_ENDPOINT_ts-cancel-service:PUT  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 143                                         NaN
# 144                                         NaN
# 145                                         NaN
# 146                                         NaN
# 147                                         NaN
#
#      N_INVOC_API_ENDPOINT_ts-inside-payment-service:drawBack  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#      AVG_EXTIME_ENTRYPOINT_ts-consign-service:updateConsign  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
#      N_INVOC_API_ENDPOINT_ts-consign-service:GET  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 143                                          NaN
# 144                                          NaN
# 145                                          NaN
# 146                                          NaN
# 147                                          NaN
#
#      N_INVOC_API_ENDPOINT_ts-consign-price-service:getPriceByWeightAndRegion
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
#
# [148 rows x 71 columns]
